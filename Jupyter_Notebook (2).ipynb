# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Areej**
#
# Data science

# %% [markdown]
# *I'm Intersting in data science because I love to discover facts from the data*
#
# *and I love Python*
#
# Even thou there are different languages you can use like
# * R
# * Java
# * Julia
#
# and other more but I prefer using Python becuase of its amazing library like
#
# * Pandas
# * Numpy
# * Matplotlib

# %% [markdown]
# ## Data Science Tools

# %% [markdown]
# |   Num| Tools         |
# |-----:|---------------|
# |     1| Tabealu       |
# |     2| Execl         |
# |     3| Jupyter       |

# %% [markdown]
# ## Arithmetic Expression

# %%
#add
print(1+2)
#multiply 
print(1*2)
#subtract
print(2-1)
#divid
print(1/2)
# Out:
# 3
# 2
# 1
# 0.5

# %% [markdown]
# ## Convert minute to hour

# %%
min=90
def min_to_hour(min):
    hour=min/60
    return hour
print(min_to_hour(min))
# Out:
# 1.5

# %% [markdown]
# ### Here how to print Hello World in python

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# So Just by using `print("Hello World")` we able to print somthing in the screen using python
# you can learn Python easily I recommend [W3School](w3schools.com/python/) Its amazing But there are other sources like
# * Free Code Camp
# * Udemy
# and other more you can discover by youeself
